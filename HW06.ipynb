# %% [markdown]
# <a href="https://colab.research.google.com/github/Venus-Yim/CS315/blob/main/HW06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import time
import matplotlib.pyplot as plt

def quickselect(A, i):
    if len(A) == 1:
        return A[0]
    pivot = random.choice(A)
    lows = [x for x in A if x < pivot]
    highs = [x for x in A if x > pivot]
    pivots = [x for x in A if x == pivot]
    if i <= len(lows):
        return quickselect(lows, i)
    elif i <= len(lows) + len(pivots):
        return pivot
    else:
        return quickselect(highs, i - len(lows) - len(pivots))

sizes = [100, 500, 1000, 5000, 10000]
times = []

for n in sizes:
    A = random.sample(range(n*10), n)
    start = time.time()
    quickselect(A, n//2)
    end = time.time()
    times.append(end - start)

plt.plot(sizes, times)
plt.xlabel("n")
plt.ylabel("Time (seconds)")
plt.title("Quickselect empirical time")
plt.show()
